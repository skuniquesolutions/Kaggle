# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# step 1 - Data Preparation:

# %%
df1 = pd.read_csv('train.csv')

# %%
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# step 2 - Identify Missing Values and Data Visulatization

# %% [markdown]
# a. To identify missing values for all columns in the DataFrame:

# %%
missing_value = df1.isnull().sum()
print(missing_value)
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
missing_value.describe()
# Out:
# count      81.000000
# mean       85.987654
# std       302.829428
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1453.000000
# dtype: float64

# %% [markdown]
# b. To identify the percentage of missing values for each column:

# %%
missing_percentage = (df1.isnull().sum()/len(df1))*100
print(missing_percentage)
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %% [markdown]
# c. To check for missing values in a specific column (e.g., 'column_name'):

# %%
#c. To check for missing values in a specific column (e.g., 'column_name'):

for i in df1.columns:
    if df1[i].isnull().sum() > 1:
        print(f"{i}:-",df1[i].isnull().sum())
# Out:
# LotFrontage:- 259
# Alley:- 1369
# MasVnrType:- 8
# MasVnrArea:- 8
# BsmtQual:- 37
# BsmtCond:- 37
# BsmtExposure:- 38
# BsmtFinType1:- 37
# BsmtFinType2:- 38
# FireplaceQu:- 690
# GarageType:- 81
# GarageYrBlt:- 81
# GarageFinish:- 81
# GarageQual:- 81
# GarageCond:- 81
# PoolQC:- 1453
# Fence:- 1179
# MiscFeature:- 1406

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df1.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
#To get a summary of missing values statistics:

missing_summary = df1.describe(include='all')
print(missing_summary)

#You can identify missing values by looking at the 'count' row.
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
#Bar chart
plt.figure(figsize=(12, 6))
missing_values = df1.isnull().sum()
missing_values.plot(kind='bar', alpha=0.7)
plt.show()

# %% [markdown]
# step 3- Summary Statistics

# %%
summary = df1.describe()
print(summary)
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# Generate summary statistics for all columns (including non-numeric) and customize percentiles
custom_summary = df1.describe(include='all', percentiles=[0.25, 0.5, 0.75])

# Print the custom summary statistics
print(custom_summary)
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
#2) Correlation Analysis

correlation_martix = df1.corr()
print(correlation_martix)
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
# Set the figure size
plt.figure(figsize=(10, 8))

sns.heatmap(correlation_martix, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Interpret the results:
#
# Positive values indicate a positive correlation (as one variable increases, the other tends to increase).
# Negative values indicate a negative correlation (as one variable increases, the other tends to decrease).
# Values close to 0 suggest a weak or no linear relationship.

# %% [markdown]
# Descriptive Statistics

# %% [markdown]
# 1)Compute basic descriptive statistics:

# %%
# Compute basic descriptive statistics for numeric columns
descriptive_stats = df1.describe()

# %%
# Customize the summary statistics with additional percentiles
custom_stats = df1.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9])
print(custom_stats)
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 10%     146.900000    20.000000    44.000000    5000.000000     5.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# 90%    1314.100000   120.000000    96.000000   14381.700000     8.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# ...

# %% [markdown]
# Step - 4 - Data Exploration Tools

# %% [markdown]
# Tableau: Tableau is a data visualization and business intelligence tool that enables you to connect to various data sources, create interactive dashboards, and explore data visually. It's known for its ease of use and the ability to quickly generate insights from data.
